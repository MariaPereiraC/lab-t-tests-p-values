# %% [markdown]
# #  T-tests and P-values
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_rel`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### One tailed t-test
# In a packing plant, a machine packs cartons with jars. It is supposed that a new machine will pack faster on the average than the machine currently used. To test that hypothesis, the times it takes each machine to pack ten cartons are recorded. The results, in seconds, are shown in the tables in the file files_for_lab/ttest_machine.xlsx. Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient evidence to show if one machine is better than the other?

# %% [markdown]
# #### Import dataset

# %%
# Your code here:
data =  open('ttest_machine.txt', 'r').read()
data
# Out:
# 'New_machine Old_machine\n42.1 42.7\n41 43.6\n41.3 43.8\n41.8 43.3\n42.4 42.5\n42.8 43.5\n43.2 43.1\n42.3 41.7\n41.8 44\n42.7 44.1'

# %%
columns = ['New_machine', 'Old_machine']
df=pd.read_csv('ttest_machine.txt', sep=' ', names=columns)
df
# Out:
#     New_machine  Old_machine
# 0   New_machine  Old_machine
# 1          42.1         42.7
# 2            41         43.6
# 3          41.3         43.8
# 4          41.8         43.3
# 5          42.4         42.5
# 6          42.8         43.5
# 7          43.2         43.1
# 8          42.3         41.7
# 9          41.8           44
# 10         42.7         44.1

# %%
df = df.drop(0)
df = df.reset_index(drop=True)
df
# Out:
#   New_machine Old_machine
# 0        42.1        42.7
# 1          41        43.6
# 2        41.3        43.8
# 3        41.8        43.3
# 4        42.4        42.5
# 5        42.8        43.5
# 6        43.2        43.1
# 7        42.3        41.7
# 8        41.8          44
# 9        42.7        44.1

# %%
df.shape
# Out:
# (10, 2)

# %%
df.dtypes
# Out:
# New_machine    object
# Old_machine    object
# dtype: object

# %%
# H0: mean of New_Machine = mean of 'Old_machine'
# H1: means of the machines are different

# %%
df['New_machine'] = df['New_machine'].astype(float)

# %%
df['Old_machine'] = df['Old_machine'].astype(float)

# %%
df.dtypes
# Out:
# New_machine    float64
# Old_machine    float64
# dtype: object

# %%
st.ttest_ind(df['New_machine'], df['Old_machine'], equal_var=False)
# Out:
# TtestResult(statistic=-3.3972307061176026, pvalue=0.00324224946631798, df=17.847298506720346)

# %%
#H0 is rejected because the p-value is lower than 0.05

# %% [markdown]
#  Markdown and LaTeX:  𝛼2

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset you have already used. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.). Use pokemon.csv

# %%
# Your code here:
pokemon =  open('pokemon.txt', 'r').read()
pokemon
# Out:
# "#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n6,CharizardMega Charizard X,Fire,Dragon,634,78,130,111,130,85,100,1,False\n6,CharizardMega Charizard Y,Fire,Flying,634,78,104,78,159,115,100,1,False\n7,Squirtle,Water,,314,44,48,65,50,64,43,1,False\n8,Wartortle,Water,,405,59,63,80,65,80,58,1,False\n9,Blastoise,Water,,530,79,83,100,85,105,78,1,False\n9,BlastoiseMega Blastoise,Water,,630,79,103,120,135,115,78,1,False\n10,Caterpie,Bug,,195,45,30,35,20,20,45,1,False\n11,Metapod,Bug,,205,50,20,55,25,25,30,1,False\n12,Butterfree,Bug,Flying,395,60,45,50,90,80,70,1
# ...

# %%
columns = ['#','Name','Type 1','Type 2','Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation','Legendary']
pokemon=pd.read_csv('pokemon.txt', sep=',', names=columns)
pokemon.head()
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  #                   Name  Type 1  Type 2  Total  HP  Attack  Defense
# 1  1              Bulbasaur   Grass  Poison    318  45      49       49
# 2  2                Ivysaur   Grass  Poison    405  60      62       63
# 3  3               Venusaur   Grass  Poison    525  80      82       83
# 4  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       65       65     45           1      False
# 2       80       80     60           1      False
# 3      100      100     80           1      False
# 4      122      120     80           1      False

# %%
pokemon = pokemon.drop(0)
pokemon = pokemon.reset_index(drop=True)
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2 Total  HP Attack Defense Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison   318  45     49      49      65
# 1  2                Ivysaur  Grass  Poison   405  60     62      63      80
# 2  3               Venusaur  Grass  Poison   525  80     82      83     100
# 3  3  VenusaurMega Venusaur  Grass  Poison   625  80    100     123     122
# 4  4             Charmander   Fire     NaN   309  39     52      43      60
#
#   Sp. Def Speed Generation Legendary
# 0      65    45          1     False
# 1      80    60          1     False
# 2     100    80          1     False
# 3     120    80          1     False
# 4      50    65          1     False

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %%
# Your code here
#s1 df that filters everything for generation 1 and s2 everything for generation 2
#loop through each of the features and do ttest
#result feature name (e.g. HP,p value for s1 and s2)

# %%
generation1_df = pokemon[pokemon['Generation'] == '1']
generation1_df
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
pokemon.dtypes
# Out:
# #             object
# Name          object
# Type 1        object
# Type 2        object
# Total         object
# HP            object
# Attack        object
# Defense       object
# Sp. Atk       object
# Sp. Def       object
# Speed         object
# Generation    object
# Legendary     object
# dtype: object

# %%
pokemon['Generation'] = pokemon['Generation'].astype(float)

# %%
generation1_df = pokemon[pokemon['Generation'] == 1]
generation1_df
# Out:
#        #                   Name   Type 1    Type 2  Total     HP  Attack  \
# 0      1              Bulbasaur    Grass    Poison  318.0   45.0    49.0
# 1      2                Ivysaur    Grass    Poison  405.0   60.0    62.0
# 2      3               Venusaur    Grass    Poison  525.0   80.0    82.0
# 3      3  VenusaurMega Venusaur    Grass    Poison  625.0   80.0   100.0
# 4      4             Charmander     Fire       NaN  309.0   39.0    52.0
# ..   ...                    ...      ...       ...    ...    ...     ...
# 161  149              Dragonite   Dragon    Flying  600.0   91.0   134.0
# 162  150                 Mewtwo  Psychic       NaN  680.0  106.0   110.0
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  780.0  106.0   190.0
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  780.0  106.0   150.0
# 165  151                    Mew  Psychic       NaN  600.0  100.0   100.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary
# ...

# %%
generation2_df = pokemon[pokemon['Generation'] == 2]
generation2_df
# Out:
#        #                     Name   Type 1  Type 2  Total     HP  Attack  \
# 166  152                Chikorita    Grass     NaN  318.0   45.0    49.0
# 167  153                  Bayleef    Grass     NaN  405.0   60.0    62.0
# 168  154                 Meganium    Grass     NaN  525.0   80.0    82.0
# 169  155                Cyndaquil     Fire     NaN  309.0   39.0    52.0
# 170  156                  Quilava     Fire     NaN  405.0   58.0    64.0
# ..   ...                      ...      ...     ...    ...    ...     ...
# 267  248                Tyranitar     Rock    Dark  600.0  100.0   134.0
# 268  248  TyranitarMega Tyranitar     Rock    Dark  700.0  100.0   164.0
# 269  249                    Lugia  Psychic  Flying  680.0  106.0    90.0
# 270  250                    Ho-oh     Fire  Flying  680.0  106.0   130.0
# 271  251                   Celebi  Psychic   Grass  600.0  100.0   100.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary
# ...

# %%
pokemon['HP'] = pokemon['HP'].astype(float)

# %%
pokemon['Attack'] = pokemon['Attack'].astype(float)

# %%
pokemon['Defense'] = pokemon['Defense'].astype(float)

# %%
pokemon['Sp. Atk'] = pokemon['Sp. Atk'].astype(float)

# %%
pokemon['Sp. Def'] = pokemon['Sp. Def'].astype(float)

# %%
pokemon['Speed'] = pokemon['Speed'].astype(float)

# %%
pokemon['Total'] = pokemon['Total'].astype(float)

# %%
legendary_df = pokemon[pokemon['Legendary'] == 'True']
legendary_df
s2=legendary_df

# %%
nonlegendary_df = pokemon[pokemon['Legendary'] == 'False']
nonlegendary_df
s1=nonlegendary_df

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}
    
    for feature in features:
        t_statistic, p_value = st.ttest_ind(s1[feature], s2[feature])
        results[feature] = p_value

    # Your code here
    
    return results

# %%
t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total'])
# Out:
# {}

# %%
st.ttest_ind(s1['HP'], s2['HP'], equal_var=False)
# Out:
# TtestResult(statistic=-8.981370483625046, pvalue=1.0026911708035284e-13, df=79.52467830799894)

# %%
t_test_features(legendary_df,nonlegendary_df,features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total'])
# Out:
# {'HP': 3.330647684846191e-15,
#  'Attack': 7.827253003205333e-24,
#  'Defense': 1.5842226094427255e-12,
#  'Sp. Atk': 6.314915770427266e-41,
#  'Sp. Def': 1.8439809580409594e-26,
#  'Speed': 2.3540754436898437e-21,
#  'Total': 3.0952457469652825e-52}

# %%
t_test_features(generation1_df,generation2_df,features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total'])
# Out:
# {'HP': 0.13791881412813622,
#  'Attack': 0.24050968418101445,
#  'Defense': 0.5407630349194362,
#  'Sp. Atk': 0.14119788176331508,
#  'Sp. Def': 0.1678122623160639,
#  'Speed': 0.0028356954812578704,
#  'Total': 0.5599140649014442}

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pokemon['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
pokemon['Result'] = 'Not dual'
pokemon.loc[(~pokemon['Type 2'].isnull()), 'Result'] = 'Dual'

# %%
pokemon['Result'].unique()
# Out:
# array(['Dual', 'Not dual'], dtype=object)

# %%
dual=pokemon[pokemon['Result'] == 'Dual']
dual
# Out:
#        #                   Name   Type 1  Type 2  Total    HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison  318.0  45.0    49.0
# 1      2                Ivysaur    Grass  Poison  405.0  60.0    62.0
# 2      3               Venusaur    Grass  Poison  525.0  80.0    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison  625.0  80.0   100.0
# 6      6              Charizard     Fire  Flying  534.0  78.0    84.0
# ..   ...                    ...      ...     ...    ...   ...     ...
# 795  719                Diancie     Rock   Fairy  600.0  50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy  700.0  50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost  600.0  80.0   110.0
# 798  720     HoopaHoopa Unbound  Psychic    Dark  680.0  80.0   160.0
# 799  721              Volcanion     Fire   Water  600.0  80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary Result
# ...

# %%
not_dual=pokemon[pokemon['Result'] == 'Not dual']
not_dual
# Out:
#        #        Name  Type 1 Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander    Fire    NaN  309.0   39.0    52.0     43.0     60.0
# 5      5  Charmeleon    Fire    NaN  405.0   58.0    64.0     58.0     80.0
# 9      7    Squirtle   Water    NaN  314.0   44.0    48.0     65.0     50.0
# 10     8   Wartortle   Water    NaN  405.0   59.0    63.0     80.0     65.0
# 11     9   Blastoise   Water    NaN  530.0   79.0    83.0    100.0     85.0
# ..   ...         ...     ...    ...    ...    ...     ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN  452.0   68.0    75.0     53.0     83.0
# 776  706      Goodra  Dragon    NaN  600.0   90.0   100.0     70.0    110.0
# 788  712    Bergmite     Ice    NaN  304.0   55.0    69.0     85.0     32.0
# 789  713     Avalugg     Ice    NaN  514.0   95.0   117.0    184.0     44.0
# 792  716     Xerneas   Fairy    NaN  680.0  126.0   131.0     95.0    131.0
#
#      Sp. Def  Speed  Generation Legendary    Result
# ...

# %%
t_test_features(not_dual,dual,features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total'])
# Out:
# {'HP': 0.11060643144431842,
#  'Attack': 0.00015741395666164396,
#  'Defense': 3.250594205757004e-08,
#  'Sp. Atk': 0.0001454917404035147,
#  'Sp. Def': 0.00010893304795534396,
#  'Speed': 0.02405141079403746,
#  'Total': 1.1749035008828752e-07}

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %%
# Your comment here
#The H0 hypotheses for all features, when we filter for legendary vs nonlegendary are rejected

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
# Your code here
#The H0 hypotheses for all features, when we filter for generation1 vs generation 2 are rejected

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
#the features are independent and the means are not the same

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.

# %%
# Your code here

#For dual vs. not dual the null hypotheses for the following features are rejected: attack, defense, Sp. Atk, Sp. Def, Speed and total. For the features HP, defense we can not not reject the null hypothesis

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
#we can not affirm that the means for HP and Defense are not the same, for the other features we can

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# Your code here

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
